# %%
import numpy as np

# set up the system
radius_m = 1
current_amps = 1

# set up the approximation
num_segments = 6

# calculate the angles
angles = np.linspace(0,2*np.pi,num_segments,endpoint=False)
#print (angles)

# calculate the loop coordinates
loop_coord_m = [np.array([radius_m*np.cos(angle), radius_m*np.sin(angle), 0]) for angle in angles]
#print (loop_coord_m)

# make the \vec{dl} array
dl_m = []

for segment_idx in list(range(0,num_segments)):
    final_idx = segment_idx % num_segments
    ini_idx = (segment_idx + 1) % num_segments
    segment = loop_coord_m[final_idx] - loop_coord_m[ini_idx]
    dl_m.append(segment)
    
#print(dl_m)

# calculate the angles
angles = np.linspace(0,2*np.pi,num_segments,endpoint=False)
#print (angles)

# calculate the loop coordinates
loop_coord_m = [np.array([radius_m*np.cos(angle), radius_m*np.sin(angle), 0]) for angle in angles]
#print (loop_coord_m)

# make the \vec{dl} array
dl_m = []

for segment_idx in list(range(0,num_segments)):
    final_idx = segment_idx % num_segments
    ini_idx = (segment_idx + 1) % num_segments
    segment = loop_coord_m[final_idx] - loop_coord_m[ini_idx]
    dl_m.append(segment)
    
#print(dl_m)

# Label the points in space we're interested in
location_dict = dict()

label = 'A'
radius = 1/5
center = np.array([1,0,0])
for idx in list(range(0,num_segments)):
    angle = angles[idx]
    location = center + np.array([radius*np.cos(angle), 0, radius*np.sin(angle)])
    #print (location)
    location_dict[chr(ord(label)+idx)] = location
    
label = 'G'
radius = 1/2
center = np.array([1,0,0])
for idx in list(range(0,num_segments)):
    angle = angles[idx]
    location = center + np.array([radius*np.cos(angle), 0, radius*np.sin(angle)])
    #print (location)
    location_dict[chr(ord(label)+idx)] = location
    
label = 'A'
radius = 1/5
center = np.array([-1,0,0])
for idx in list(range(0,num_segments)):
    angle = angles[idx]
    location = center + np.array([radius*np.cos(angle), 0, radius*np.sin(angle)])
    #print (location)
    key = chr(ord(label)+idx)
    location_dict[key*2] = location
    
label = 'G'
radius = 1/2
center = np.array([-1,0,0])
for idx in list(range(0,num_segments)):
    angle = angles[idx]
    location = center + np.array([radius*np.cos(angle), 0, radius*np.sin(angle)])
    #print (location)
    key = chr(ord(label)+idx)
    location_dict[key*2] = location
    
location_dict['Q'] = np.array([0,0,2])
#print (location_dict)

# %%
# choose the location you're interested in
#location_m = np.array([-0.09, 0, -0.0173])
location_m = location_dict['B']

# net magnetic field
b_net = np.array([0,0,0])

# first element in dl_m matches with second element in loop_coord_m
for idx in list(range(0,num_segments)):
    dl = dl_m[idx]
    r = location_m - loop_coord_m[(idx+1) % num_segments]
    #r = np.array([0,0,2])- loop_coord_m[(idx+1) % num_segments]
    dB = np.cross(dl,r)/(np.linalg.norm(r)**3)
    b_net = b_net + dB
    
    print("segment" + repr(1+idx))
    print("dl: " + repr(dl))
    print("r ini: " + repr(loop_coord_m[(idx+1) % num_segments]))
    #print("r ini: " + repr(loop_coord_m[(idx) % num_segments]))
    print("r vec: " + repr(r))
    print("r hat: " + repr(r/np.linalg.norm(r)))
    print("r length: " + repr(np.linalg.norm(r)))
    print("cross: " + repr(np.cross(dl,r))) #/np.linalg.norm(r)))
    print("dB * 10^(-7): " + repr(dB))
    print("loc: " + repr(location_m))

print('++++++++++++++++')
print("B_net: " + repr(b_net))
# Out:
# segment1
# dl: array([ 0.5      , -0.8660254,  0.       ])
# r ini: array([ 0.5      ,  0.8660254,  0.       ])
# r vec: array([ 0.6       , -0.8660254 ,  0.17320508])
# r hat: array([ 0.56195149, -0.81110711,  0.16222142])
# r length: 1.0677078252031311
# cross: array([-0.15      , -0.08660254,  0.08660254])
# dB * 10^(-7): array([-0.12323498, -0.07114975,  0.07114975])
# loc: array([ 1.1       ,  0.        ,  0.17320508])
# segment2
# dl: array([  1.00000000e+00,  -1.11022302e-16,   0.00000000e+00])
# r ini: array([-0.5      ,  0.8660254,  0.       ])
# r vec: array([ 1.6       , -0.8660254 ,  0.17320508])
# r hat: array([ 0.87548105, -0.47386802,  0.0947736 ])
# r length: 1.8275666882497064
# cross: array([ -1.92296269e-17,  -1.73205081e-01,  -8.66025404e-01])
# dB * 10^(-7): array([ -3.15029451e-18,  -2.83753304e-02,  -1.41876652e-01])
# loc: array([ 1.1       ,  0.        ,  0.17320508])
# segment3
# dl: array([ 0.5      ,  0.8660254,  0.       ])
# r ini: array([ -1.00000000e+00,   1.22464680e-16,   0.00000000e+00])
# r vec: array([  2.10000000e+00,  -1.22464680e-16,   1.73205081e-01])
# r hat: array([  9.96615896e-01,  -5.81191651e-17,   8.21994937e-02])
# r length: 2.1071307505705477
# cross: array([ 0.15      , -0.08660254, -1.81865335])
# dB * 10^(-7): array([ 0.01603307, -0.0092567 , -0.19439069])
# loc: array([ 1.1       ,  0.        ,  0.17320508])
# segment4
# dl: array([-0.5      ,  0.8660254,  0.       ])
# r ini: array([-0.5      , -0.8660254,  0.       ])
# r vec: array([ 1.6       ,  0.8660254 ,  0.17320508])
# r hat: array([ 0.87548105,  0.47386802,  0.0947736 ])
# r length: 1.8275666882497068
# cross: array([ 0.15      ,  0.08660254, -1.81865335])
# dB * 10^(-7): array([ 0.02457376,  0.01418767, -0.29794097])
# loc: array([ 1.1       ,  0.        ,  0.17320508])
# segment5
# dl: array([ -1.00000000e+00,   5.55111512e-16,   0.00000000e+00])
# r ini: array([ 0.5      , -0.8660254,  0.       ])
# r vec: array([ 0.6       ,  0.8660254 ,  0.17320508])
# r hat: array([ 0.56195149,  0.81110711,  0.16222142])
# r length: 1.067707825203132
# cross: array([  9.61481343e-17,   1.73205081e-01,  -8.66025404e-01])
# dB * 10^(-7): array([  7.89920863e-17,   1.42299492e-01,  -7.11497461e-01])
# loc: array([ 1.1       ,  0.        ,  0.17320508])
# segment6
# dl: array([-0.5      , -0.8660254,  0.       ])
# r ini: array([ 1.,  0.,  0.])
# r vec: array([ 0.1       ,  0.        ,  0.17320508])
# r hat: array([ 0.5      ,  0.       ,  0.8660254])
# r length: 0.20000000000000004
# cross: array([-0.15      ,  0.08660254,  0.08660254])
# dB * 10^(-7): array([-18.75      ,  10.82531755,  10.82531755])
# loc: array([ 1.1       ,  0.        ,  0.17320508])
# ++++++++++++++++
# B_net: array([-18.83262814,  10.87302293,   9.55076152])
